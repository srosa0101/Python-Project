# %% [markdown]
# I have selected Franklin Roosevelt, and I will be comparing Numbers Scoring Above 65 for the Borough of Manhattan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv("https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv", index_col=0)

# %%
df.head(160)
# Out:
#                                         School Name School Level  \
# School DBN
# 01M034               P.S. 034 Franklin D. Roosevelt          K-8
# 01M034               P.S. 034 Franklin D. Roosevelt          K-8
# 01M034               P.S. 034 Franklin D. Roosevelt          K-8
# 01M140                       P.S. 140 Nathan Straus          K-8
# 01M140                       P.S. 140 Nathan Straus          K-8
# ...                                             ...          ...
# 01M509                      Marta Valle High School  High school
# 01M509                      Marta Valle High School  High school
# 01M509                      Marta Valle High School  High school
# 01M509                      Marta Valle High School  High school
# 01M515      Lower East Side Preparatory High School  High school
#
#                                Regents Exam  Year  Total Tested Mean Score  \
# School DBN
# 01M034                  Common Core Algebra  2017             4          s
# ...

# %%
df.drop(['Number Scoring 80 or Above', 'Percent Scoring 80 or Above', 'Number Scoring CR', 'Percent Scoring CR'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-5c16579a0e7b> in <cell line: 1>()
# ----> 1 df.drop(['Number Scoring 80 or Above', 'Percent Scoring 80 or Above', 'Number Scoring CR', 'Percent Scoring CR'], axis=1, inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %% [markdown]
# i removed columns

# %%
df
# Out:
#                                School Name School Level         Regents Exam  \
# School DBN
# 01M034      P.S. 034 Franklin D. Roosevelt          K-8  Common Core Algebra
# 01M034      P.S. 034 Franklin D. Roosevelt          K-8   Living Environment
# 01M034      P.S. 034 Franklin D. Roosevelt          K-8   Living Environment
# 01M140              P.S. 140 Nathan Straus          K-8  Common Core Algebra
# 01M140              P.S. 140 Nathan Straus          K-8  Common Core Algebra
# ...                                    ...          ...                  ...
# 84X717                Icahn Charter School          K-8   Living Environment
# 84X717                Icahn Charter School          K-8   Living Environment
# 84X717                Icahn Charter School          K-8   Living Environment
# 84X717                Icahn Charter School          K-8   Living Environment
# 84X717                Icahn Charter School          K-8   Living Environment
#
# ...

# %%
df[df['Number Scoring Below 65'].str.contains('0')]
# Out:
#                            School Name School Level  \
# School DBN
# 01M184            P.S. 184m Shuang Wen          K-8
# 01M292      Orchard Collegiate Academy  High school
# 01M292      Orchard Collegiate Academy  High school
# 01M292      Orchard Collegiate Academy  High school
# 01M292      Orchard Collegiate Academy  High school
# ...                                ...          ...
# 84X717            Icahn Charter School          K-8
# 84X717            Icahn Charter School          K-8
# 84X717            Icahn Charter School          K-8
# 84X717            Icahn Charter School          K-8
# 84X717            Icahn Charter School          K-8
#
#                            Regents Exam  Total Tested Number Scoring Below 65
# School DBN
# 01M184              Common Core Algebra            51                       0
# 01M292               Integrated Algebra            63                      30
# 01M292               Living Environment            74                      50
# ...

# %% [markdown]
# cleaning rows that had no numbers

# %%
cleaning rows that had no number

# %%
duplicates=df.duplicated(subset=None, keep='first')
print(duplicates)
# Out:
# School DBN
# 01M034    False
# 01M034    False
# 01M034    False
# 01M140    False
# 01M140    False
#           ...
# 84X717     True
# 84X717    False
# 84X717    False
# 84X717    False
# 84X717     True
# Length: 212331, dtype: bool

# %%
df.drop_duplicates(subset=None, keep='first', inplace=True)

# %% [markdown]
# removing duplicates

# %%
df
# Out:
#                                School Name School Level         Regents Exam  \
# School DBN
# 01M034      P.S. 034 Franklin D. Roosevelt          K-8  Common Core Algebra
# 01M034      P.S. 034 Franklin D. Roosevelt          K-8   Living Environment
# 01M034      P.S. 034 Franklin D. Roosevelt          K-8   Living Environment
# 01M140              P.S. 140 Nathan Straus          K-8  Common Core Algebra
# 01M140              P.S. 140 Nathan Straus          K-8  Common Core Algebra
# ...                                    ...          ...                  ...
# 84X717                Icahn Charter School          K-8   Living Environment
# 84X717                Icahn Charter School          K-8   Living Environment
# 84X717                Icahn Charter School          K-8   Living Environment
# 84X717                Icahn Charter School          K-8   Living Environment
# 84X717                Icahn Charter School          K-8   Living Environment
#
# ...

# %%
df[df['Number Scoring Below 65'].str.contains('0')]
# Out:
#                               School Name     School Level  \
# School DBN
# 01M184               P.S. 184m Shuang Wen              K-8
# 01M292         Orchard Collegiate Academy      High school
# 01M292         Orchard Collegiate Academy      High school
# 01M292         Orchard Collegiate Academy      High school
# 01M292         Orchard Collegiate Academy      High school
# ...                                   ...              ...
# 84X704        KIPP Academy Charter School  K-12 all grades
# 84X706      Harriet Tubman Charter School              K-8
# 84X717               Icahn Charter School              K-8
# 84X717               Icahn Charter School              K-8
# 84X717               Icahn Charter School              K-8
#
#                            Regents Exam  Total Tested Number Scoring Below 65
# School DBN
# 01M184              Common Core Algebra            51                       0
# ...

# %%
df.groupby(['Regents Exam'])['Number Scoring Below 65'].count()
# Out:
# Regents Exam
# Algebra2/Trigonometry               7614
# Common Core Algebra                23734
# Common Core Algebra2                6210
# Common Core English                16327
# Common Core Geometry               12248
# English                             9205
# Geometry                            6373
# Global History and Geography       17118
# Integrated Algebra                  8829
# Living Environment                 21617
# Physical Settings/Chemistry         8693
# Physical Settings/Earth Science    12936
# Physical Settings/Physics           4085
# U.S. History and Government        17621
# Name: Number Scoring Below 65, dtype: int64

# %%
df.groupby(['School Level'])['Number Scoring Below 65'].count()
# Out:
# School Level
# Elementary                              9
# High school                        125728
# Junior High-Intermediate-Middle     11144
# K-12 all grades                      6922
# K-8                                  4254
# Secondary School                    24562
# Name: Number Scoring Below 65, dtype: int64

# %% [markdown]
# count by subject

# %%
df.groupby(['School Level'])['Number Scoring Below 65'].count().sort_values(ascending = False).plot(kind="bar")
# Out:
# <Axes: xlabel='School Level'>

# %% [markdown]
# visualization for data

# %% [markdown]
# I wanted to compare Franklin D. Roosevelt High School with other schools in NYC to show how they compared when taking the US History and Government Regents.
#
# 90 students in Franklin D. Roosevelt scored 65 or below vs across all of NYC which was 17621.
